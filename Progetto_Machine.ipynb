# %% [markdown]
# ## Libraries

# %%
# [IMPORTS] Core & Audio Processing
import os
import glob
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import copy

# [IMPORTS] Audio & Visualization
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

# [IMPORTS] PyTorch & ML
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio.transforms as T
import torch.nn.init as init
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from sklearn.svm import SVR
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.pipeline import Pipeline

# [IMPORTS] Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

# [IMPORTS] Other
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset loading from google drive

# %%
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import tarfile
# Percorsi di origine e destinazione
drive_root = '/content/drive/MyDrive/mel_sequences_final'
base_output = '/content/mel_dataset'

# Cartelle di output organizzate
split_dirs = {
    'train': os.path.join(base_output, 'train'),
    'valid': os.path.join(base_output, 'valid'),
    'test': os.path.join(base_output, 'test')
}

# Crea/Reset cartelle di output
for split, out_dir in split_dirs.items():
    os.makedirs(out_dir, exist_ok=True)

# Mappa dei file da estrarre in ciascuna cartella
tar_map = {
    'mel_sequences_train.tar.gz': split_dirs['train'],
    'mel_sequences_valid.tar.gz': split_dirs['valid'],
    'mel_sequences_test.tar.gz':  split_dirs['test'],
}

# Estrazione per split
for tar_name, output_dir in tar_map.items():
    tar_path = os.path.join(drive_root, tar_name)
    print(f"📦 Estraendo {tar_name} in {output_dir}...")
    with tarfile.open(tar_path, 'r:gz') as tar:
        tar.extractall(path=output_dir)

print("Estrazione completata. Cartelle create:")
for split, path in split_dirs.items():
    print(f"  📁 {split}: {path}")
# Out:
# 📦 Estraendo mel_sequences_train.tar.gz in /content/mel_dataset/train...
# 📦 Estraendo mel_sequences_valid.tar.gz in /content/mel_dataset/valid...
# 📦 Estraendo mel_sequences_test.tar.gz in /content/mel_dataset/test...
# Estrazione completata. Cartelle create:
#   📁 train: /content/mel_dataset/train
#   📁 valid: /content/mel_dataset/valid
#   📁 test: /content/mel_dataset/test

# %%
class MelSequenceDataset(Dataset):

    def __init__(self, mel_dir, transform=None):
        self.files = sorted(glob.glob(os.path.join(mel_dir, '*.npz')))
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        data = np.load(self.files[idx])
        mel = data['mel']
        label = data['label']
        if self.transform:
            mel = self.transform(mel)
        return torch.tensor(mel, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# %%
train_dataset = MelSequenceDataset('/content/mel_dataset/train')
valid_dataset = MelSequenceDataset('/content/mel_dataset/valid')
test_dataset  = MelSequenceDataset('/content/mel_dataset/test')

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
devel_loader = DataLoader(valid_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class CNNRNNAttention(nn.Module):
    def __init__(self, n_mels=128, hidden_size=128, n_lstm_layers=2):
        super(CNNRNNAttention, self).__init__()

        self.conv_block = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=3, padding=1),
            nn.BatchNorm2d(8),
            nn.ELU(),
            nn.MaxPool2d(2),

            nn.Conv2d(8, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.ELU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ELU(),
            nn.MaxPool2d(4),

        )

        self.rnn = nn.LSTM(input_size=512, hidden_size=hidden_size,
                           num_layers=n_lstm_layers, batch_first=True, bidirectional=True)

        self.attn = nn.Linear(2*hidden_size, 1)

        self.fc_valence = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4*hidden_size, 1),
        )

        self.initialize_weights()

    def forward(self, x):
        batch_size, seq_len, C, H, W = x.shape

        x = x.view(batch_size * seq_len, C, H, W)
        x = self.conv_block(x)

        x = x.view(batch_size, seq_len, -1)
        rnn_out, _ = self.rnn(x)

        scores = torch.tanh(self.attn(rnn_out))
        alpha  = torch.softmax(scores, dim=1)
        context = torch.sum(rnn_out * alpha, dim=1)

        last_out=rnn_out[:, -1, :]
        out=torch.cat([context,last_out], dim=1)

        valence_output = self.fc_valence(out)

        return valence_output


    def initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

            elif isinstance(m, nn.Linear):
                init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

            elif isinstance(m, nn.LSTM):
                for name, param in m.named_parameters():
                    if 'weight_ih' in name:
                        init.xavier_uniform_(param.data)
                    elif 'weight_hh' in name:
                        init.orthogonal_(param.data)
                    elif 'bias' in name:
                        param.data.fill_(0)
                        # Inizializzazione dei forget gate bias a 1
                        n = param.size(0)
                        param.data[n//4:n//2].fill_(1)

            elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)


    def extract_features(model, x):

      with torch.no_grad():
        batch_size, seq_len, C, H, W = x.shape
        x = x.view(batch_size * seq_len, C, H, W)
        x = model.conv_block(x)
        x = x.view(batch_size, seq_len, -1)
        rnn_out, _ = model.rnn(x)
        scores = torch.tanh(model.attn(rnn_out))
        alpha = torch.softmax(scores, dim=1)
        context = torch.sum(rnn_out * alpha, dim=1)
        last_out = rnn_out[:, -1, :]
        out = torch.cat([context, last_out], dim=1)
        return out

# %%
import os
import numpy as np
import torch

def extract_and_save_batches(model, dataloader, save_dir, prefix='train', device='cuda'):
    model.eval()
    os.makedirs(save_dir, exist_ok=True)

    with torch.no_grad():
        for i, (x, y) in enumerate(dataloader):
            x, y = x.to(device), y.to(device)
            feats = model.extract_features(x).cpu().numpy()
            labels = y[:, -1, 0].cpu().numpy()

            np.save(os.path.join(save_dir, f'{prefix}_features_batch_{i}.npy'), feats)
            np.save(os.path.join(save_dir, f'{prefix}_labels_batch_{i}.npy'), labels)

            print(f"Batch {i} salvato.")

# %%
def merge_batches_to_npz(save_dir, prefix, out_path):
    feat_files = sorted([f for f in os.listdir(save_dir) if f.startswith(f'{prefix}_features')])
    label_files = sorted([f for f in os.listdir(save_dir) if f.startswith(f'{prefix}_labels')])

    feats = [np.load(os.path.join(save_dir, f)) for f in feat_files]
    labels = [np.load(os.path.join(save_dir, f)) for f in label_files]

    X = np.concatenate(feats, axis=0)
    y = np.concatenate(labels, axis=0)
    np.savez_compressed(out_path, X=X, y=y)
    print(f"Salvato {prefix} in {out_path}")

# %%
def ccc(y_true, y_pred, eps=1e-8):
    mean_true = np.mean(y_true)
    mean_pred = np.mean(y_pred)
    var_true = np.var(y_true)
    var_pred = np.var(y_pred)
    covariance = np.mean((y_true - mean_true) * (y_pred - mean_pred))
    ccc = (2 * covariance) / (var_true + var_pred + (mean_true - mean_pred) ** 2 + eps)
    return ccc

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNRNNAttention().to(device)
model.load_state_dict(torch.load( '/content/best.ckpt', map_location='cpu',weights_only=False)['model_state'])


extract_and_save_batches(model, train_loader, save_dir='features/', prefix='train', device=device)
extract_and_save_batches(model, devel_loader, save_dir='features/', prefix='val', device=device)
extract_and_save_batches(model, test_loader, save_dir='features/', prefix='test', device=device)
# Out:
# Batch 0 salvato.
# Batch 1 salvato.
# Batch 2 salvato.
# Batch 3 salvato.
# Batch 4 salvato.
# Batch 5 salvato.
# Batch 6 salvato.
# Batch 7 salvato.
# Batch 8 salvato.
# Batch 9 salvato.
# Batch 10 salvato.
# Batch 11 salvato.
# Batch 12 salvato.
# Batch 13 salvato.
# Batch 14 salvato.
# Batch 15 salvato.
# Batch 16 salvato.
# Batch 17 salvato.
# Batch 18 salvato.
# Batch 19 salvato.
# Batch 20 salvato.
# Batch 21 salvato.
# Batch 22 salvato.
# Batch 23 salvato.
# Batch 24 salvato.
# Batch 25 salvato.
# Batch 26 salvato.
# Batch 27 salvato.
# Batch 28 salvato.
# Batch 29 salvato.
# Batch 30 salvato.
# Batch 31 salvato.
# Batch 32 salvato.
# Batch 33 salvato.
# Batch 34 salvato.
# Batch 35 salvato.
# Batch 36 salvato.
# Batch 37 salvato.
# Batch 38 salvato.
# Batch 39 salvato.
# Batch 40 salvato.
# Batch 41 salvato.
# Batch 42 salvato.
# Batch 43 salvato.
# Batch 44 salvato.
# Batch 45 salvato.
# Batch 46 salvato.
# Batch 47 salvato.
# Batch 48 salvato.
# Batch 49 salvato.
# Batch 50 salvato.
# Batch 51 salvato.
# Batch 52 salvato.
# Batch 53 salvato.
# Batch 54 salvato.
# Batch 55 salvato.
# Batch 56 salvato.
# Batch 57 salvato.
# Batch 58 salvato.
# Batch 59 salvato.
# Batch 60 salvato.
# Batch 61 salvato.
# Batch 62 salvato.
# Batch 63 salvato.
# Batch 64 salvato.
# Batch 65 salvato.
# Batch 66 salvato.
# Batch 67 salvato.
# Batch 68 salvato.
# Batch 69 salvato.
# Batch 70 salvato.
# Batch 71 salvato.
# Batch 72 salvato.
# Batch 73 salvato.
# Batch 74 salvato.
# Batch 75 salvato.
# Batch 76 salvato.
# Batch 77 salvato.
# Batch 78 salvato.
# Batch 79 salvato.
# Batch 80 salvato.
# Batch 81 salvato.
# Batch 82 salvato.
# Batch 83 salvato.
# Batch 84 salvato.
# Batch 85 salvato.
# Batch 86 salvato.
# Batch 87 salvato.
# Batch 88 salvato.
# Batch 89 salvato.
# Batch 90 salvato.
# Batch 91 salvato.
# Batch 92 salvato.
# Batch 93 salvato.
# Batch 94 salvato.
# Batch 95 salvato.
# Batch 96 salvato.
# Batch 97 salvato.
# Batch 98 salvato.
# Batch 99 salvato.
# Batch 100 salvato.
# Batch 101 salvato.
# Batch 102 salvato.
# Batch 103 salvato.
# Batch 104 salvato.
# Batch 105 salvato.
# Batch 106 salvato.
# Batch 107 salvato.
# Batch 108 salvato.
# Batch 109 salvato.
# Batch 110 salvato.
# Batch 111 salvato.
# Batch 112 salvato.
# Batch 113 salvato.
# Batch 114 salvato.
# Batch 115 salvato.
# Batch 116 salvato.
# Batch 117 salvato.
# Batch 118 salvato.
# Batch 119 salvato.
# Batch 120 salvato.
# Batch 121 salvato.
# Batch 122 salvato.
# Batch 123 salvato.
# Batch 124 salvato.
# Batch 125 salvato.
# Batch 126 salvato.
# Batch 127 salvato.
# Batch 128 salvato.
# Batch 129 salvato.
# Batch 130 salvato.
# Batch 131 salvato.
# Batch 132 salvato.
# Batch 133 salvato.
# Batch 134 salvato.
# Batch 135 salvato.
# Batch 136 salvato.
# Batch 137 salvato.
# Batch 138 salvato.
# Batch 139 salvato.
# Batch 140 salvato.
# Batch 141 salvato.
# Batch 142 salvato.
# Batch 143 salvato.
# Batch 144 salvato.
# Batch 145 salvato.
# Batch 146 salvato.
# Batch 147 salvato.
# Batch 148 salvato.
# Batch 149 salvato.
# Batch 150 salvato.
# Batch 151 salvato.
# Batch 152 salvato.
# Batch 153 salvato.
# Batch 154 salvato.
# Batch 155 salvato.
# Batch 156 salvato.
# Batch 157 salvato.
# Batch 158 salvato.
# Batch 159 salvato.
# Batch 160 salvato.
# Batch 161 salvato.
# Batch 162 salvato.
# Batch 163 salvato.
# Batch 164 salvato.
# Batch 165 salvato.
# Batch 166 salvato.
# Batch 167 salvato.
# Batch 168 salvato.
# Batch 169 salvato.
# Batch 170 salvato.
# Batch 171 salvato.
# Batch 172 salvato.
# Batch 173 salvato.
# Batch 174 salvato.
# Batch 175 salvato.
# Batch 176 salvato.
# Batch 177 salvato.
# Batch 178 salvato.
# Batch 179 salvato.
# Batch 180 salvato.
# Batch 181 salvato.
# Batch 182 salvato.
# Batch 183 salvato.
# Batch 184 salvato.
# Batch 185 salvato.
# Batch 186 salvato.
# Batch 187 salvato.
# Batch 188 salvato.
# Batch 189 salvato.
# Batch 190 salvato.
# Batch 191 salvato.
# Batch 192 salvato.
# Batch 193 salvato.
# Batch 194 salvato.
# Batch 195 salvato.
# Batch 196 salvato.
# Batch 197 salvato.
# Batch 198 salvato.
# Batch 199 salvato.
# Batch 200 salvato.
# Batch 201 salvato.
# Batch 202 salvato.
# Batch 203 salvato.
# Batch 204 salvato.
# Batch 205 salvato.
# Batch 206 salvato.
# Batch 207 salvato.
# Batch 208 salvato.
# Batch 209 salvato.
# Batch 210 salvato.
# Batch 211 salvato.
# Batch 212 salvato.
# Batch 213 salvato.
# Batch 214 salvato.
# Batch 215 salvato.
# Batch 216 salvato.
# Batch 217 salvato.
# Batch 218 salvato.
# Batch 219 salvato.
# Batch 220 salvato.
# Batch 221 salvato.
# Batch 222 salvato.
# Batch 223 salvato.
# Batch 224 salvato.
# Batch 225 salvato.
# Batch 226 salvato.
# Batch 227 salvato.
# Batch 228 salvato.
# Batch 229 salvato.
# Batch 230 salvato.
# Batch 231 salvato.
# Batch 232 salvato.
# Batch 233 salvato.
# Batch 234 salvato.
# Batch 235 salvato.
# Batch 236 salvato.
# Batch 237 salvato.
# Batch 238 salvato.
# Batch 239 salvato.
# Batch 240 salvato.
# Batch 241 salvato.
# Batch 242 salvato.
# Batch 243 salvato.
# Batch 244 salvato.
# Batch 245 salvato.
# Batch 246 salvato.
# Batch 247 salvato.
# Batch 248 salvato.
# Batch 249 salvato.
# Batch 250 salvato.
# Batch 251 salvato.
# Batch 252 salvato.
# Batch 253 salvato.
# Batch 254 salvato.
# Batch 255 salvato.
# Batch 256 salvato.
# Batch 257 salvato.
# Batch 258 salvato.
# Batch 259 salvato.
# Batch 260 salvato.
# Batch 261 salvato.
# Batch 262 salvato.
# Batch 263 salvato.
# Batch 264 salvato.
# Batch 265 salvato.
# Batch 266 salvato.
# Batch 267 salvato.
# Batch 268 salvato.
# Batch 269 salvato.
# Batch 270 salvato.
# Batch 271 salvato.
# Batch 272 salvato.
# Batch 273 salvato.
# Batch 274 salvato.
# Batch 275 salvato.
# Batch 276 salvato.
# Batch 277 salvato.
# Batch 278 salvato.
# Batch 279 salvato.
# Batch 280 salvato.
# Batch 281 salvato.
# Batch 282 salvato.
# Batch 283 salvato.
# Batch 284 salvato.
# Batch 285 salvato.
# Batch 286 salvato.
# Batch 287 salvato.
# Batch 288 salvato.
# Batch 289 salvato.
# Batch 290 salvato.
# Batch 291 salvato.
# Batch 292 salvato.
# Batch 293 salvato.
# Batch 294 salvato.
# Batch 295 salvato.
# Batch 296 salvato.
# Batch 297 salvato.
# Batch 298 salvato.
# Batch 299 salvato.
# Batch 300 salvato.
# Batch 301 salvato.
# Batch 302 salvato.
# Batch 303 salvato.
# Batch 304 salvato.
# Batch 305 salvato.
# Batch 306 salvato.
# Batch 307 salvato.
# Batch 308 salvato.
# Batch 309 salvato.
# Batch 310 salvato.
# Batch 311 salvato.
# Batch 312 salvato.
# Batch 313 salvato.
# Batch 314 salvato.
# Batch 315 salvato.
# Batch 316 salvato.
# Batch 317 salvato.
# Batch 318 salvato.
# Batch 319 salvato.
# Batch 320 salvato.
# Batch 321 salvato.
# Batch 322 salvato.
# Batch 323 salvato.
# Batch 324 salvato.
# Batch 325 salvato.
# Batch 326 salvato.
# Batch 327 salvato.
# Batch 328 salvato.
# Batch 329 salvato.
# Batch 330 salvato.
# Batch 331 salvato.
# Batch 332 salvato.
# Batch 333 salvato.
# Batch 334 salvato.
# Batch 335 salvato.
# Batch 336 salvato.
# Batch 337 salvato.
# Batch 338 salvato.
# Batch 339 salvato.
# Batch 340 salvato.
# Batch 341 salvato.
# Batch 342 salvato.
# Batch 343 salvato.
# Batch 344 salvato.
# Batch 345 salvato.
# Batch 346 salvato.
# Batch 347 salvato.
# Batch 348 salvato.
# Batch 349 salvato.
# Batch 350 salvato.
# Batch 351 salvato.
# Batch 352 salvato.
# Batch 353 salvato.
# Batch 354 salvato.
# Batch 355 salvato.
# Batch 356 salvato.
# Batch 357 salvato.
# Batch 358 salvato.
# Batch 359 salvato.
# Batch 360 salvato.
# Batch 361 salvato.
# Batch 362 salvato.
# Batch 363 salvato.
# Batch 364 salvato.
# Batch 365 salvato.
# Batch 366 salvato.
# Batch 367 salvato.
# Batch 368 salvato.
# Batch 369 salvato.
# Batch 370 salvato.
# Batch 371 salvato.
# Batch 372 salvato.
# Batch 373 salvato.
# Batch 374 salvato.
# Batch 375 salvato.
# Batch 376 salvato.
# Batch 377 salvato.
# Batch 378 salvato.
# Batch 379 salvato.
# Batch 380 salvato.
# Batch 381 salvato.
# Batch 382 salvato.
# Batch 383 salvato.
# Batch 384 salvato.
# Batch 385 salvato.
# Batch 386 salvato.
# Batch 387 salvato.
# Batch 388 salvato.
# Batch 389 salvato.
# Batch 390 salvato.
# Batch 391 salvato.
# Batch 392 salvato.
# Batch 393 salvato.
# Batch 394 salvato.
# Batch 395 salvato.
# Batch 396 salvato.
# Batch 397 salvato.
# Batch 398 salvato.
# Batch 399 salvato.
# Batch 400 salvato.
# Batch 401 salvato.
# Batch 402 salvato.
# Batch 403 salvato.
# Batch 404 salvato.
# Batch 405 salvato.
# Batch 406 salvato.
# Batch 407 salvato.
# Batch 408 salvato.
# Batch 409 salvato.
# Batch 410 salvato.
# Batch 411 salvato.
# Batch 412 salvato.
# Batch 413 salvato.
# Batch 414 salvato.
# Batch 415 salvato.
# Batch 416 salvato.
# Batch 417 salvato.
# Batch 418 salvato.
# Batch 419 salvato.
# Batch 420 salvato.
# Batch 421 salvato.
# Batch 422 salvato.
# Batch 423 salvato.
# Batch 424 salvato.
# Batch 425 salvato.
# Batch 426 salvato.
# Batch 427 salvato.
# Batch 428 salvato.
# Batch 429 salvato.
# Batch 430 salvato.
# Batch 431 salvato.
# Batch 432 salvato.
# Batch 433 salvato.
# Batch 434 salvato.
# Batch 435 salvato.
# Batch 436 salvato.
# Batch 437 salvato.
# Batch 438 salvato.
# Batch 439 salvato.
# Batch 440 salvato.
# Batch 441 salvato.
# Batch 442 salvato.
# Batch 443 salvato.
# Batch 444 salvato.
# Batch 445 salvato.
# Batch 446 salvato.
# Batch 447 salvato.
# Batch 448 salvato.
# Batch 449 salvato.
# Batch 450 salvato.
# Batch 451 salvato.
# Batch 452 salvato.
# Batch 453 salvato.
# Batch 454 salvato.
# Batch 455 salvato.
# Batch 456 salvato.
# Batch 457 salvato.
# Batch 458 salvato.
# Batch 459 salvato.
# Batch 460 salvato.
# Batch 461 salvato.
# Batch 462 salvato.
# Batch 463 salvato.
# Batch 464 salvato.
# Batch 465 salvato.
# Batch 466 salvato.
# Batch 467 salvato.
# Batch 468 salvato.
# Batch 469 salvato.
# Batch 470 salvato.
# Batch 471 salvato.
# Batch 472 salvato.
# Batch 473 salvato.
# Batch 474 salvato.
# Batch 475 salvato.
# Batch 476 salvato.
# Batch 477 salvato.
# Batch 478 salvato.
# Batch 479 salvato.
# Batch 480 salvato.
# Batch 481 salvato.
# Batch 482 salvato.
# Batch 483 salvato.
# Batch 484 salvato.
# Batch 485 salvato.
# Batch 486 salvato.
# Batch 487 salvato.
# Batch 488 salvato.
# Batch 489 salvato.
# Batch 490 salvato.
# Batch 491 salvato.
# Batch 492 salvato.
# Batch 493 salvato.
# Batch 494 salvato.
# Batch 495 salvato.
# Batch 496 salvato.
# Batch 497 salvato.
# Batch 498 salvato.
# Batch 499 salvato.
# Batch 500 salvato.
# Batch 501 salvato.
# Batch 502 salvato.
# Batch 503 salvato.
# Batch 504 salvato.
# Batch 505 salvato.
# Batch 506 salvato.
# Batch 507 salvato.
# Batch 508 salvato.
# Batch 509 salvato.
# Batch 510 salvato.
# Batch 511 salvato.
# Batch 512 salvato.
# Batch 513 salvato.
# Batch 514 salvato.
# Batch 515 salvato.
# Batch 516 salvato.
# Batch 517 salvato.
# Batch 518 salvato.
# Batch 519 salvato.
# Batch 520 salvato.
# Batch 521 salvato.
# Batch 522 salvato.
# Batch 523 salvato.
# Batch 524 salvato.
# Batch 525 salvato.
# Batch 526 salvato.
# Batch 527 salvato.
# Batch 528 salvato.
# Batch 529 salvato.
# Batch 530 salvato.
# Batch 531 salvato.
# Batch 532 salvato.
# Batch 533 salvato.
# Batch 534 salvato.
# Batch 535 salvato.
# Batch 536 salvato.
# Batch 537 salvato.
# Batch 538 salvato.
# Batch 539 salvato.
# Batch 540 salvato.
# Batch 541 salvato.
# Batch 542 salvato.
# Batch 543 salvato.
# Batch 544 salvato.
# Batch 545 salvato.
# Batch 546 salvato.
# Batch 547 salvato.
# Batch 548 salvato.
# Batch 549 salvato.
# Batch 550 salvato.
# Batch 551 salvato.
# Batch 552 salvato.
# Batch 553 salvato.
# Batch 554 salvato.
# Batch 555 salvato.
# Batch 556 salvato.
# Batch 557 salvato.
# Batch 558 salvato.
# Batch 559 salvato.
# Batch 560 salvato.
# Batch 561 salvato.
# Batch 562 salvato.
# Batch 563 salvato.
# Batch 564 salvato.
# Batch 565 salvato.
# Batch 566 salvato.
# Batch 567 salvato.
# Batch 568 salvato.
# Batch 569 salvato.
# Batch 570 salvato.
# Batch 571 salvato.
# Batch 572 salvato.
# Batch 573 salvato.
# Batch 574 salvato.
# Batch 575 salvato.
# Batch 576 salvato.
# Batch 577 salvato.
# Batch 578 salvato.
# Batch 579 salvato.
# Batch 580 salvato.
# Batch 581 salvato.
# Batch 582 salvato.
# Batch 583 salvato.
# Batch 584 salvato.
# Batch 585 salvato.
# Batch 586 salvato.
# Batch 587 salvato.
# Batch 588 salvato.
# Batch 589 salvato.
# Batch 590 salvato.
# Batch 591 salvato.
# Batch 592 salvato.
# Batch 593 salvato.
# Batch 594 salvato.
# Batch 595 salvato.
# Batch 596 salvato.
# Batch 597 salvato.
# Batch 598 salvato.
# Batch 599 salvato.
# Batch 600 salvato.
# Batch 601 salvato.
# Batch 602 salvato.
# Batch 603 salvato.
# Batch 604 salvato.
# Batch 605 salvato.
# Batch 606 salvato.
# Batch 607 salvato.
# Batch 608 salvato.
# Batch 609 salvato.
# Batch 610 salvato.
# Batch 611 salvato.
# Batch 612 salvato.
# Batch 613 salvato.
# Batch 614 salvato.
# Batch 615 salvato.
# Batch 616 salvato.
# Batch 617 salvato.
# Batch 618 salvato.
# Batch 619 salvato.
# Batch 620 salvato.
# Batch 621 salvato.
# Batch 622 salvato.
# Batch 623 salvato.
# Batch 624 salvato.
# Batch 625 salvato.
# Batch 626 salvato.
# Batch 627 salvato.
# Batch 628 salvato.
# Batch 629 salvato.
# Batch 630 salvato.
# Batch 631 salvato.
# Batch 632 salvato.
# Batch 633 salvato.
# Batch 634 salvato.
# Batch 635 salvato.
# Batch 636 salvato.
# Batch 637 salvato.
# Batch 638 salvato.
# Batch 639 salvato.
# Batch 640 salvato.
# Batch 641 salvato.
# Batch 642 salvato.
# Batch 643 salvato.
# Batch 644 salvato.
# Batch 645 salvato.
# Batch 646 salvato.
# Batch 647 salvato.
# Batch 648 salvato.
# Batch 649 salvato.
# Batch 650 salvato.
# Batch 651 salvato.
# Batch 652 salvato.
# Batch 653 salvato.
# Batch 654 salvato.
# Batch 655 salvato.
# Batch 656 salvato.
# Batch 657 salvato.
# Batch 658 salvato.
# Batch 659 salvato.
# Batch 660 salvato.
# Batch 661 salvato.
# Batch 662 salvato.
# Batch 663 salvato.
# Batch 664 salvato.
# Batch 665 salvato.
# Batch 666 salvato.
# Batch 667 salvato.
# Batch 668 salvato.
# Batch 669 salvato.
# Batch 670 salvato.
# Batch 671 salvato.
# Batch 672 salvato.
# Batch 673 salvato.
# Batch 674 salvato.
# Batch 675 salvato.
# Batch 676 salvato.
# Batch 677 salvato.
# Batch 678 salvato.
# Batch 679 salvato.
# Batch 680 salvato.
# Batch 681 salvato.
# Batch 682 salvato.
# Batch 683 salvato.
# Batch 684 salvato.
# Batch 685 salvato.
# Batch 686 salvato.
# Batch 687 salvato.
# Batch 688 salvato.
# Batch 689 salvato.
# Batch 690 salvato.
# Batch 691 salvato.
# Batch 692 salvato.
# Batch 693 salvato.
# Batch 694 salvato.
# Batch 695 salvato.
# Batch 696 salvato.
# Batch 697 salvato.
# Batch 698 salvato.
# Batch 699 salvato.
# Batch 700 salvato.
# Batch 701 salvato.
# Batch 702 salvato.
# Batch 703 salvato.
# Batch 704 salvato.
# Batch 705 salvato.
# Batch 706 salvato.
# Batch 707 salvato.
# Batch 708 salvato.
# Batch 709 salvato.
# Batch 710 salvato.
# Batch 711 salvato.
# Batch 712 salvato.
# Batch 713 salvato.
# Batch 714 salvato.
# Batch 715 salvato.
# Batch 716 salvato.
# Batch 717 salvato.
# Batch 718 salvato.
# Batch 719 salvato.
# Batch 720 salvato.
# Batch 721 salvato.
# Batch 722 salvato.
# Batch 723 salvato.
# Batch 724 salvato.
# Batch 725 salvato.
# Batch 726 salvato.
# Batch 727 salvato.
# Batch 728 salvato.
# Batch 729 salvato.
# Batch 730 salvato.
# Batch 731 salvato.
# Batch 732 salvato.
# Batch 733 salvato.
# Batch 734 salvato.
# Batch 735 salvato.
# Batch 736 salvato.
# Batch 737 salvato.
# Batch 738 salvato.
# Batch 739 salvato.
# Batch 740 salvato.
# Batch 741 salvato.
# Batch 742 salvato.
# Batch 743 salvato.
# Batch 744 salvato.
# Batch 745 salvato.
# Batch 746 salvato.
# Batch 747 salvato.
# Batch 748 salvato.
# Batch 749 salvato.
# Batch 750 salvato.
# Batch 751 salvato.
# Batch 752 salvato.
# Batch 753 salvato.
# Batch 754 salvato.
# Batch 755 salvato.
# Batch 756 salvato.
# Batch 757 salvato.
# Batch 758 salvato.
# Batch 759 salvato.
# Batch 760 salvato.
# Batch 761 salvato.
# Batch 762 salvato.
# Batch 763 salvato.
# Batch 764 salvato.
# Batch 765 salvato.
# Batch 766 salvato.
# Batch 767 salvato.
# Batch 768 salvato.
# Batch 769 salvato.
# Batch 770 salvato.
# Batch 771 salvato.
# Batch 772 salvato.
# Batch 773 salvato.
# Batch 774 salvato.
# Batch 775 salvato.
# Batch 776 salvato.
# Batch 777 salvato.
# Batch 778 salvato.
# Batch 779 salvato.
# Batch 780 salvato.
# Batch 781 salvato.
# Batch 782 salvato.
# Batch 783 salvato.
# Batch 784 salvato.
# Batch 785 salvato.
# Batch 786 salvato.
# Batch 787 salvato.
# Batch 788 salvato.
# Batch 789 salvato.
# Batch 790 salvato.
# Batch 791 salvato.
# Batch 792 salvato.
# Batch 793 salvato.
# Batch 794 salvato.
# Batch 795 salvato.
# Batch 796 salvato.
# Batch 797 salvato.
# Batch 798 salvato.
# Batch 799 salvato.
# Batch 800 salvato.
# Batch 801 salvato.
# Batch 802 salvato.
# Batch 803 salvato.
# Batch 804 salvato.
# Batch 805 salvato.
# Batch 806 salvato.
# Batch 807 salvato.
# Batch 808 salvato.
# Batch 809 salvato.
# Batch 810 salvato.
# Batch 811 salvato.
# Batch 812 salvato.
# Batch 813 salvato.
# Batch 814 salvato.
# Batch 815 salvato.
# Batch 816 salvato.
# Batch 817 salvato.
# Batch 818 salvato.
# Batch 819 salvato.
# Batch 820 salvato.
# Batch 821 salvato.
# Batch 822 salvato.
# Batch 823 salvato.
# Batch 824 salvato.
# Batch 825 salvato.
# Batch 826 salvato.
# Batch 827 salvato.
# Batch 828 salvato.
# Batch 829 salvato.
# Batch 830 salvato.
# Batch 831 salvato.
# Batch 832 salvato.
# Batch 833 salvato.
# Batch 834 salvato.
# Batch 835 salvato.
# Batch 836 salvato.
# Batch 837 salvato.
# Batch 838 salvato.
# Batch 839 salvato.
# Batch 840 salvato.
# Batch 841 salvato.
# Batch 842 salvato.
# Batch 843 salvato.
# Batch 844 salvato.
# Batch 845 salvato.
# Batch 846 salvato.
# Batch 847 salvato.
# Batch 848 salvato.
# Batch 849 salvato.
# Batch 850 salvato.
# Batch 851 salvato.
# Batch 852 salvato.
# Batch 853 salvato.
# Batch 854 salvato.
# Batch 855 salvato.
# Batch 856 salvato.
# Batch 857 salvato.
# Batch 858 salvato.
# Batch 859 salvato.
# Batch 860 salvato.
# Batch 861 salvato.
# Batch 862 salvato.
# Batch 863 salvato.
# Batch 864 salvato.
# Batch 865 salvato.
# Batch 866 salvato.
# Batch 867 salvato.
# Batch 868 salvato.
# Batch 869 salvato.
# Batch 870 salvato.
# Batch 871 salvato.
# Batch 872 salvato.
# Batch 873 salvato.
# Batch 874 salvato.
# Batch 875 salvato.
# Batch 876 salvato.
# Batch 877 salvato.
# Batch 878 salvato.
# Batch 879 salvato.
# Batch 880 salvato.
# Batch 881 salvato.
# Batch 882 salvato.
# Batch 883 salvato.
# Batch 884 salvato.
# Batch 885 salvato.
# Batch 886 salvato.
# Batch 887 salvato.
# Batch 888 salvato.
# Batch 889 salvato.
# Batch 890 salvato.
# Batch 891 salvato.
# Batch 892 salvato.
# Batch 893 salvato.
# Batch 894 salvato.
# Batch 895 salvato.
# Batch 896 salvato.
# Batch 897 salvato.
# Batch 898 salvato.
# Batch 899 salvato.
# Batch 900 salvato.
# Batch 901 salvato.
# Batch 902 salvato.
# Batch 903 salvato.
# Batch 904 salvato.
# Batch 905 salvato.
# Batch 906 salvato.
# Batch 907 salvato.
# Batch 908 salvato.
# Batch 909 salvato.
# Batch 910 salvato.
# Batch 911 salvato.
# Batch 912 salvato.
# Batch 913 salvato.
# Batch 914 salvato.
# Batch 915 salvato.
# Batch 916 salvato.
# Batch 917 salvato.
# Batch 918 salvato.
# Batch 919 salvato.
# Batch 920 salvato.
# Batch 921 salvato.
# Batch 922 salvato.
# Batch 923 salvato.
# Batch 924 salvato.
# Batch 925 salvato.
# Batch 926 salvato.
# Batch 927 salvato.
# Batch 928 salvato.
# Batch 929 salvato.
# Batch 930 salvato.
# Batch 931 salvato.
# Batch 932 salvato.
# Batch 933 salvato.
# Batch 934 salvato.
# Batch 935 salvato.
# Batch 936 salvato.
# Batch 937 salvato.
# Batch 938 salvato.
# Batch 939 salvato.
# Batch 940 salvato.
# Batch 941 salvato.
# Batch 942 salvato.
# Batch 943 salvato.
# Batch 944 salvato.
# Batch 945 salvato.
# Batch 946 salvato.
# Batch 947 salvato.
# Batch 948 salvato.
# Batch 949 salvato.
# Batch 950 salvato.
# Batch 951 salvato.
# Batch 952 salvato.
# Batch 953 salvato.
# Batch 954 salvato.
# Batch 955 salvato.
# Batch 956 salvato.
# Batch 957 salvato.
# Batch 958 salvato.
# Batch 959 salvato.
# Batch 960 salvato.
# Batch 961 salvato.
# Batch 962 salvato.
# Batch 963 salvato.
# Batch 964 salvato.
# Batch 965 salvato.
# Batch 966 salvato.
# Batch 967 salvato.
# Batch 968 salvato.
# Batch 969 salvato.
# Batch 970 salvato.
# Batch 971 salvato.
# Batch 972 salvato.
# Batch 973 salvato.
# Batch 974 salvato.
# Batch 975 salvato.
# Batch 976 salvato.
# Batch 977 salvato.
# Batch 978 salvato.
# Batch 979 salvato.
# Batch 980 salvato.
# Batch 981 salvato.
# Batch 982 salvato.
# Batch 983 salvato.
# Batch 984 salvato.
# Batch 985 salvato.
# Batch 986 salvato.
# Batch 987 salvato.
# Batch 988 salvato.
# Batch 989 salvato.
# Batch 990 salvato.
# Batch 991 salvato.
# Batch 992 salvato.
# Batch 993 salvato.
# Batch 994 salvato.
# Batch 995 salvato.
# Batch 996 salvato.
# Batch 997 salvato.
# Batch 998 salvato.
# Batch 999 salvato.
# Batch 1000 salvato.
# Batch 1001 salvato.
# Batch 1002 salvato.
# Batch 1003 salvato.
# Batch 1004 salvato.
# Batch 1005 salvato.
# Batch 1006 salvato.
# Batch 1007 salvato.
# Batch 1008 salvato.
# Batch 1009 salvato.
# Batch 1010 salvato.
# Batch 1011 salvato.
# Batch 1012 salvato.
# Batch 1013 salvato.
# Batch 1014 salvato.
# Batch 1015 salvato.
# Batch 1016 salvato.
# Batch 1017 salvato.
# Batch 1018 salvato.
# Batch 1019 salvato.
# Batch 1020 salvato.
# Batch 1021 salvato.
# Batch 1022 salvato.
# Batch 1023 salvato.
# Batch 1024 salvato.
# Batch 1025 salvato.
# Batch 1026 salvato.
# Batch 1027 salvato.
# Batch 1028 salvato.
# Batch 1029 salvato.
# Batch 1030 salvato.
# Batch 1031 salvato.
# Batch 1032 salvato.
# Batch 1033 salvato.
# Batch 1034 salvato.
# Batch 1035 salvato.
# Batch 1036 salvato.
# Batch 1037 salvato.
# Batch 1038 salvato.
# Batch 1039 salvato.
# Batch 1040 salvato.
# Batch 1041 salvato.
# Batch 1042 salvato.
# Batch 1043 salvato.
# Batch 1044 salvato.
# Batch 1045 salvato.
# Batch 1046 salvato.
# Batch 1047 salvato.
# Batch 1048 salvato.
# Batch 1049 salvato.
# Batch 1050 salvato.
# Batch 1051 salvato.
# Batch 1052 salvato.
# Batch 1053 salvato.
# Batch 1054 salvato.
# Batch 1055 salvato.
# Batch 1056 salvato.
# Batch 1057 salvato.
# Batch 1058 salvato.
# Batch 1059 salvato.
# Batch 1060 salvato.
# Batch 1061 salvato.
# Batch 1062 salvato.
# Batch 1063 salvato.
# Batch 1064 salvato.
# Batch 1065 salvato.
# Batch 1066 salvato.
# Batch 1067 salvato.
# Batch 1068 salvato.
# Batch 1069 salvato.
# Batch 1070 salvato.
# Batch 1071 salvato.
# Batch 1072 salvato.
# Batch 1073 salvato.
# Batch 1074 salvato.
# Batch 1075 salvato.
# Batch 1076 salvato.
# Batch 1077 salvato.
# Batch 1078 salvato.
# Batch 1079 salvato.
# Batch 1080 salvato.
# Batch 1081 salvato.
# Batch 1082 salvato.
# Batch 1083 salvato.
# Batch 1084 salvato.
# Batch 1085 salvato.
# Batch 1086 salvato.
# Batch 1087 salvato.
# Batch 1088 salvato.
# Batch 1089 salvato.
# Batch 1090 salvato.
# Batch 1091 salvato.
# Batch 1092 salvato.
# Batch 1093 salvato.
# Batch 1094 salvato.
# Batch 1095 salvato.
# Batch 1096 salvato.
# Batch 1097 salvato.
# Batch 1098 salvato.
# Batch 1099 salvato.
# Batch 1100 salvato.
# Batch 1101 salvato.
# Batch 1102 salvato.
# Batch 1103 salvato.
# Batch 1104 salvato.
# Batch 1105 salvato.
# Batch 1106 salvato.
# Batch 1107 salvato.
# Batch 1108 salvato.
# Batch 1109 salvato.
# Batch 1110 salvato.
# Batch 1111 salvato.
# Batch 1112 salvato.
# Batch 1113 salvato.
# Batch 1114 salvato.
# Batch 1115 salvato.
# Batch 1116 salvato.
# Batch 1117 salvato.
# Batch 1118 salvato.
# Batch 1119 salvato.
# Batch 1120 salvato.
# Batch 1121 salvato.
# Batch 1122 salvato.
# Batch 1123 salvato.
# Batch 1124 salvato.
# Batch 1125 salvato.
# Batch 1126 salvato.
# Batch 1127 salvato.
# Batch 1128 salvato.
# Batch 1129 salvato.
# Batch 1130 salvato.
# Batch 1131 salvato.
# Batch 1132 salvato.
# Batch 1133 salvato.
# Batch 1134 salvato.
# Batch 1135 salvato.
# Batch 1136 salvato.
# Batch 1137 salvato.
# Batch 1138 salvato.
# Batch 1139 salvato.
# Batch 1140 salvato.
# Batch 1141 salvato.
# Batch 1142 salvato.
# Batch 1143 salvato.
# Batch 1144 salvato.
# Batch 1145 salvato.
# Batch 1146 salvato.
# Batch 1147 salvato.
# Batch 1148 salvato.
# Batch 1149 salvato.
# Batch 1150 salvato.
# Batch 1151 salvato.
# Batch 1152 salvato.
# Batch 1153 salvato.
# Batch 1154 salvato.
# Batch 1155 salvato.
# Batch 1156 salvato.
# Batch 1157 salvato.
# Batch 1158 salvato.
# Batch 1159 salvato.
# Batch 1160 salvato.
# Batch 1161 salvato.
# Batch 1162 salvato.
# Batch 1163 salvato.
# Batch 1164 salvato.
# Batch 1165 salvato.
# Batch 1166 salvato.
# Batch 1167 salvato.
# Batch 1168 salvato.
# Batch 1169 salvato.
# Batch 1170 salvato.
# Batch 1171 salvato.
# Batch 1172 salvato.
# Batch 1173 salvato.
# Batch 1174 salvato.
# Batch 1175 salvato.
# Batch 1176 salvato.
# Batch 1177 salvato.
# Batch 1178 salvato.
# Batch 1179 salvato.
# Batch 1180 salvato.
# Batch 1181 salvato.
# Batch 1182 salvato.
# Batch 1183 salvato.
# Batch 1184 salvato.
# Batch 1185 salvato.
# Batch 1186 salvato.
# Batch 1187 salvato.
# Batch 1188 salvato.
# Batch 1189 salvato.
# Batch 1190 salvato.
# Batch 1191 salvato.
# Batch 1192 salvato.
# Batch 1193 salvato.
# Batch 1194 salvato.
# Batch 1195 salvato.
# Batch 1196 salvato.
# Batch 1197 salvato.
# Batch 1198 salvato.
# Batch 1199 salvato.
# Batch 1200 salvato.
# Batch 1201 salvato.
# Batch 1202 salvato.
# Batch 1203 salvato.
# Batch 1204 salvato.
# Batch 1205 salvato.
# Batch 1206 salvato.
# Batch 1207 salvato.
# Batch 1208 salvato.
# Batch 1209 salvato.
# Batch 1210 salvato.
# Batch 1211 salvato.
# Batch 1212 salvato.
# Batch 1213 salvato.
# Batch 1214 salvato.
# Batch 1215 salvato.
# Batch 1216 salvato.
# Batch 1217 salvato.
# Batch 1218 salvato.
# Batch 1219 salvato.
# Batch 1220 salvato.
# Batch 1221 salvato.
# Batch 1222 salvato.
# Batch 1223 salvato.
# Batch 1224 salvato.
# Batch 1225 salvato.
# Batch 1226 salvato.
# Batch 1227 salvato.
# Batch 1228 salvato.
# Batch 1229 salvato.
# Batch 1230 salvato.
# Batch 1231 salvato.
# Batch 1232 salvato.
# Batch 1233 salvato.
# Batch 1234 salvato.
# Batch 1235 salvato.
# Batch 1236 salvato.
# Batch 1237 salvato.
# Batch 1238 salvato.
# Batch 1239 salvato.
# Batch 1240 salvato.
# Batch 1241 salvato.
# Batch 1242 salvato.
# Batch 1243 salvato.
# Batch 1244 salvato.
# Batch 1245 salvato.
# Batch 1246 salvato.
# Batch 1247 salvato.
# Batch 1248 salvato.
# Batch 1249 salvato.
# Batch 1250 salvato.
# Batch 1251 salvato.
# Batch 1252 salvato.
# Batch 1253 salvato.
# Batch 1254 salvato.
# Batch 1255 salvato.
# Batch 1256 salvato.
# Batch 1257 salvato.
# Batch 1258 salvato.
# Batch 1259 salvato.
# Batch 1260 salvato.
# Batch 1261 salvato.
# Batch 1262 salvato.
# Batch 1263 salvato.
# Batch 1264 salvato.
# Batch 1265 salvato.
# Batch 1266 salvato.
# Batch 1267 salvato.
# Batch 1268 salvato.
# Batch 1269 salvato.
# Batch 1270 salvato.
# Batch 1271 salvato.
# Batch 1272 salvato.
# Batch 1273 salvato.
# Batch 1274 salvato.
# Batch 1275 salvato.
# Batch 1276 salvato.
# Batch 1277 salvato.
# Batch 1278 salvato.
# Batch 1279 salvato.
# Batch 1280 salvato.
# Batch 1281 salvato.
# Batch 1282 salvato.
# Batch 1283 salvato.
# Batch 1284 salvato.
# Batch 1285 salvato.
# Batch 1286 salvato.
# Batch 1287 salvato.
# Batch 1288 salvato.
# Batch 1289 salvato.
# Batch 1290 salvato.
# Batch 1291 salvato.
# Batch 1292 salvato.
# Batch 1293 salvato.
# Batch 1294 salvato.
# Batch 1295 salvato.
# Batch 1296 salvato.
# Batch 1297 salvato.
# Batch 1298 salvato.
# Batch 1299 salvato.
# Batch 1300 salvato.
# Batch 1301 salvato.
# Batch 1302 salvato.
# Batch 1303 salvato.
# Batch 1304 salvato.
# Batch 1305 salvato.
# Batch 1306 salvato.
# Batch 1307 salvato.
# Batch 1308 salvato.
# Batch 1309 salvato.
# Batch 1310 salvato.
# Batch 1311 salvato.
# Batch 1312 salvato.
# Batch 1313 salvato.
# Batch 1314 salvato.
# Batch 1315 salvato.
# Batch 1316 salvato.
# Batch 1317 salvato.
# Batch 1318 salvato.
# Batch 1319 salvato.
# Batch 1320 salvato.
# Batch 1321 salvato.
# Batch 1322 salvato.
# Batch 1323 salvato.
# Batch 1324 salvato.
# Batch 1325 salvato.
# Batch 1326 salvato.
# Batch 1327 salvato.
# Batch 1328 salvato.
# Batch 1329 salvato.
# Batch 1330 salvato.
# Batch 1331 salvato.
# Batch 1332 salvato.
# Batch 1333 salvato.
# Batch 1334 salvato.
# Batch 1335 salvato.
# Batch 1336 salvato.
# Batch 1337 salvato.
# Batch 1338 salvato.
# Batch 1339 salvato.
# Batch 1340 salvato.
# Batch 1341 salvato.
# Batch 1342 salvato.
# Batch 1343 salvato.
# Batch 1344 salvato.
# Batch 1345 salvato.
# Batch 1346 salvato.
# Batch 1347 salvato.
# Batch 1348 salvato.
# Batch 1349 salvato.
# Batch 1350 salvato.
# Batch 1351 salvato.
# Batch 1352 salvato.
# Batch 1353 salvato.
# Batch 1354 salvato.
# Batch 1355 salvato.
# Batch 1356 salvato.
# Batch 1357 salvato.
# Batch 1358 salvato.
# Batch 1359 salvato.
# Batch 1360 salvato.
# Batch 1361 salvato.
# Batch 1362 salvato.
# Batch 1363 salvato.
# Batch 1364 salvato.
# Batch 1365 salvato.
# Batch 1366 salvato.
# Batch 1367 salvato.
# Batch 1368 salvato.
# Batch 1369 salvato.
# Batch 1370 salvato.
# Batch 1371 salvato.
# Batch 1372 salvato.
# Batch 1373 salvato.
# Batch 1374 salvato.
# Batch 1375 salvato.
# Batch 1376 salvato.
# Batch 1377 salvato.
# Batch 1378 salvato.
# Batch 1379 salvato.
# Batch 1380 salvato.
# Batch 1381 salvato.
# Batch 1382 salvato.
# Batch 1383 salvato.
# Batch 1384 salvato.
# Batch 1385 salvato.
# Batch 1386 salvato.
# Batch 1387 salvato.
# Batch 1388 salvato.
# Batch 1389 salvato.
# Batch 1390 salvato.
# Batch 1391 salvato.
# Batch 1392 salvato.
# Batch 1393 salvato.
# Batch 1394 salvato.
# Batch 1395 salvato.
# Batch 1396 salvato.
# Batch 1397 salvato.
# Batch 1398 salvato.
# Batch 1399 salvato.
# Batch 1400 salvato.
# Batch 1401 salvato.
# Batch 1402 salvato.
# Batch 1403 salvato.
# Batch 1404 salvato.
# Batch 1405 salvato.
# Batch 1406 salvato.
# Batch 1407 salvato.
# Batch 1408 salvato.
# Batch 1409 salvato.
# Batch 1410 salvato.
# Batch 1411 salvato.
# Batch 1412 salvato.
# Batch 1413 salvato.
# Batch 1414 salvato.
# Batch 1415 salvato.
# Batch 1416 salvato.
# Batch 1417 salvato.
# Batch 1418 salvato.
# Batch 1419 salvato.
# Batch 1420 salvato.
# Batch 1421 salvato.
# Batch 1422 salvato.
# Batch 1423 salvato.
# Batch 1424 salvato.
# Batch 1425 salvato.
# Batch 1426 salvato.
# Batch 1427 salvato.
# Batch 1428 salvato.
# Batch 1429 salvato.
# Batch 1430 salvato.
# Batch 1431 salvato.
# Batch 1432 salvato.
# Batch 1433 salvato.
# Batch 1434 salvato.
# Batch 1435 salvato.
# Batch 1436 salvato.
# Batch 1437 salvato.
# Batch 1438 salvato.
# Batch 1439 salvato.
# Batch 1440 salvato.
# Batch 1441 salvato.
# Batch 1442 salvato.
# Batch 1443 salvato.
# Batch 1444 salvato.
# Batch 1445 salvato.
# Batch 1446 salvato.
# Batch 1447 salvato.
# Batch 1448 salvato.
# Batch 1449 salvato.
# Batch 1450 salvato.
# Batch 1451 salvato.
# Batch 1452 salvato.
# Batch 1453 salvato.
# Batch 1454 salvato.
# Batch 1455 salvato.
# Batch 1456 salvato.
# Batch 1457 salvato.
# Batch 1458 salvato.
# Batch 1459 salvato.
# Batch 1460 salvato.
# Batch 1461 salvato.
# Batch 1462 salvato.
# Batch 1463 salvato.
# Batch 1464 salvato.
# Batch 1465 salvato.
# Batch 1466 salvato.
# Batch 1467 salvato.
# Batch 1468 salvato.
# Batch 1469 salvato.
# Batch 1470 salvato.
# Batch 1471 salvato.
# Batch 1472 salvato.
# Batch 1473 salvato.
# Batch 1474 salvato.
# Batch 1475 salvato.
# Batch 1476 salvato.
# Batch 1477 salvato.
# Batch 1478 salvato.
# Batch 1479 salvato.
# Batch 1480 salvato.
# Batch 1481 salvato.
# Batch 1482 salvato.
# Batch 1483 salvato.
# Batch 1484 salvato.
# Batch 1485 salvato.
# Batch 1486 salvato.
# Batch 1487 salvato.
# Batch 1488 salvato.
# Batch 1489 salvato.
# Batch 1490 salvato.
# Batch 1491 salvato.
# Batch 1492 salvato.
# Batch 1493 salvato.
# Batch 1494 salvato.
# Batch 1495 salvato.
# Batch 1496 salvato.
# Batch 1497 salvato.
# Batch 1498 salvato.
# Batch 1499 salvato.
# Batch 1500 salvato.
# Batch 1501 salvato.
# Batch 1502 salvato.
# Batch 1503 salvato.
# Batch 1504 salvato.
# Batch 1505 salvato.
# Batch 1506 salvato.
# Batch 1507 salvato.
# Batch 1508 salvato.
# Batch 1509 salvato.
# Batch 1510 salvato.
# Batch 1511 salvato.
# Batch 1512 salvato.
# Batch 1513 salvato.
# Batch 1514 salvato.
# Batch 1515 salvato.
# Batch 1516 salvato.
# Batch 1517 salvato.
# Batch 1518 salvato.
# Batch 1519 salvato.
# Batch 1520 salvato.
# Batch 1521 salvato.
# Batch 1522 salvato.
# Batch 1523 salvato.
# Batch 1524 salvato.
# Batch 1525 salvato.
# Batch 1526 salvato.
# Batch 1527 salvato.
# Batch 1528 salvato.
# Batch 1529 salvato.
# Batch 1530 salvato.
# Batch 1531 salvato.
# Batch 1532 salvato.
# Batch 1533 salvato.
# Batch 1534 salvato.
# Batch 1535 salvato.
# Batch 1536 salvato.
# Batch 1537 salvato.
# Batch 1538 salvato.
# Batch 1539 salvato.
# Batch 1540 salvato.
# Batch 1541 salvato.
# Batch 1542 salvato.
# Batch 1543 salvato.
# Batch 1544 salvato.
# Batch 1545 salvato.
# Batch 1546 salvato.
# Batch 1547 salvato.
# Batch 1548 salvato.
# Batch 1549 salvato.
# Batch 1550 salvato.
# Batch 0 salvato.
# Batch 1 salvato.
# Batch 2 salvato.
# Batch 3 salvato.
# Batch 4 salvato.
# Batch 5 salvato.
# Batch 6 salvato.
# Batch 7 salvato.
# Batch 8 salvato.
# Batch 9 salvato.
# Batch 10 salvato.
# Batch 11 salvato.
# Batch 12 salvato.
# Batch 13 salvato.
# Batch 14 salvato.
# Batch 15 salvato.
# Batch 16 salvato.
# Batch 17 salvato.
# Batch 18 salvato.
# Batch 19 salvato.
# Batch 20 salvato.
# Batch 21 salvato.
# Batch 22 salvato.
# Batch 23 salvato.
# Batch 24 salvato.
# Batch 25 salvato.
# Batch 26 salvato.
# Batch 27 salvato.
# Batch 28 salvato.
# Batch 29 salvato.
# Batch 30 salvato.
# Batch 31 salvato.
# Batch 32 salvato.
# Batch 33 salvato.
# Batch 34 salvato.
# Batch 35 salvato.
# Batch 36 salvato.
# Batch 37 salvato.
# Batch 38 salvato.
# Batch 39 salvato.
# Batch 40 salvato.
# Batch 41 salvato.
# Batch 42 salvato.
# Batch 43 salvato.
# Batch 44 salvato.
# Batch 45 salvato.
# Batch 46 salvato.
# Batch 47 salvato.
# Batch 48 salvato.
# Batch 49 salvato.
# Batch 50 salvato.
# Batch 51 salvato.
# Batch 52 salvato.
# Batch 53 salvato.
# Batch 54 salvato.
# Batch 55 salvato.
# Batch 56 salvato.
# Batch 57 salvato.
# Batch 58 salvato.
# Batch 59 salvato.
# Batch 60 salvato.
# Batch 61 salvato.
# Batch 62 salvato.
# Batch 63 salvato.
# Batch 64 salvato.
# Batch 65 salvato.
# Batch 66 salvato.
# Batch 67 salvato.
# Batch 68 salvato.
# Batch 69 salvato.
# Batch 70 salvato.
# Batch 71 salvato.
# Batch 72 salvato.
# Batch 73 salvato.
# Batch 74 salvato.
# Batch 75 salvato.
# Batch 76 salvato.
# Batch 77 salvato.
# Batch 78 salvato.
# Batch 79 salvato.
# Batch 80 salvato.
# Batch 81 salvato.
# Batch 82 salvato.
# Batch 83 salvato.
# Batch 84 salvato.
# Batch 85 salvato.
# Batch 86 salvato.
# Batch 87 salvato.
# Batch 88 salvato.
# Batch 89 salvato.
# Batch 90 salvato.
# Batch 91 salvato.
# Batch 92 salvato.
# Batch 93 salvato.
# Batch 94 salvato.
# Batch 95 salvato.
# Batch 96 salvato.
# Batch 97 salvato.
# Batch 98 salvato.
# Batch 99 salvato.
# Batch 100 salvato.
# Batch 101 salvato.
# Batch 102 salvato.
# Batch 103 salvato.
# Batch 104 salvato.
# Batch 105 salvato.
# Batch 106 salvato.
# Batch 107 salvato.
# Batch 108 salvato.
# Batch 109 salvato.
# Batch 110 salvato.
# Batch 111 salvato.
# Batch 112 salvato.
# Batch 113 salvato.
# Batch 114 salvato.
# Batch 115 salvato.
# Batch 116 salvato.
# Batch 117 salvato.
# Batch 118 salvato.
# Batch 119 salvato.
# Batch 120 salvato.
# Batch 121 salvato.
# Batch 122 salvato.
# Batch 123 salvato.
# Batch 124 salvato.
# Batch 125 salvato.
# Batch 126 salvato.
# Batch 127 salvato.
# Batch 128 salvato.
# Batch 129 salvato.
# Batch 130 salvato.
# Batch 131 salvato.
# Batch 132 salvato.
# Batch 133 salvato.
# Batch 134 salvato.
# Batch 135 salvato.
# Batch 136 salvato.
# Batch 137 salvato.
# Batch 138 salvato.
# Batch 139 salvato.
# Batch 140 salvato.
# Batch 141 salvato.
# Batch 142 salvato.
# Batch 143 salvato.
# Batch 144 salvato.
# Batch 145 salvato.
# Batch 146 salvato.
# Batch 147 salvato.
# Batch 148 salvato.
# Batch 149 salvato.
# Batch 150 salvato.
# Batch 151 salvato.
# Batch 152 salvato.
# Batch 153 salvato.
# Batch 154 salvato.
# Batch 155 salvato.
# Batch 156 salvato.
# Batch 157 salvato.
# Batch 158 salvato.
# Batch 159 salvato.
# Batch 160 salvato.
# Batch 161 salvato.
# Batch 162 salvato.
# Batch 163 salvato.
# Batch 164 salvato.
# Batch 165 salvato.
# Batch 166 salvato.
# Batch 167 salvato.
# Batch 168 salvato.
# Batch 169 salvato.
# Batch 170 salvato.
# Batch 171 salvato.
# Batch 172 salvato.
# Batch 173 salvato.
# Batch 174 salvato.
# Batch 175 salvato.
# Batch 176 salvato.
# Batch 177 salvato.
# Batch 178 salvato.
# Batch 179 salvato.
# Batch 180 salvato.
# Batch 181 salvato.
# Batch 182 salvato.
# Batch 183 salvato.
# Batch 184 salvato.
# Batch 185 salvato.
# Batch 186 salvato.
# Batch 187 salvato.
# Batch 188 salvato.
# Batch 189 salvato.
# Batch 190 salvato.
# Batch 191 salvato.
# Batch 192 salvato.
# Batch 193 salvato.
# Batch 194 salvato.
# Batch 195 salvato.
# Batch 196 salvato.
# Batch 197 salvato.
# Batch 198 salvato.
# Batch 199 salvato.
# Batch 200 salvato.
# Batch 201 salvato.
# Batch 202 salvato.
# Batch 203 salvato.
# Batch 204 salvato.
# Batch 205 salvato.
# Batch 206 salvato.
# Batch 207 salvato.
# Batch 208 salvato.
# Batch 209 salvato.
# Batch 210 salvato.
# Batch 211 salvato.
# Batch 212 salvato.
# Batch 213 salvato.
# Batch 214 salvato.
# Batch 215 salvato.
# Batch 216 salvato.
# Batch 217 salvato.
# Batch 218 salvato.
# Batch 219 salvato.
# Batch 220 salvato.
# Batch 221 salvato.
# Batch 222 salvato.
# Batch 223 salvato.
# Batch 224 salvato.
# Batch 225 salvato.
# Batch 226 salvato.
# Batch 227 salvato.
# Batch 228 salvato.
# Batch 229 salvato.
# Batch 230 salvato.
# Batch 231 salvato.
# Batch 232 salvato.
# Batch 233 salvato.
# Batch 234 salvato.
# Batch 235 salvato.
# Batch 236 salvato.
# Batch 237 salvato.
# Batch 238 salvato.
# Batch 239 salvato.
# Batch 240 salvato.
# Batch 241 salvato.
# Batch 242 salvato.
# Batch 243 salvato.
# Batch 244 salvato.
# Batch 245 salvato.
# Batch 246 salvato.
# Batch 247 salvato.
# Batch 248 salvato.
# Batch 249 salvato.
# Batch 250 salvato.
# Batch 251 salvato.
# Batch 252 salvato.
# Batch 253 salvato.
# Batch 254 salvato.
# Batch 255 salvato.
# Batch 256 salvato.
# Batch 257 salvato.
# Batch 258 salvato.
# Batch 259 salvato.
# Batch 260 salvato.
# Batch 261 salvato.
# Batch 262 salvato.
# Batch 263 salvato.
# Batch 264 salvato.
# Batch 265 salvato.
# Batch 266 salvato.
# Batch 267 salvato.
# Batch 268 salvato.
# Batch 269 salvato.
# Batch 270 salvato.
# Batch 271 salvato.
# Batch 272 salvato.
# Batch 273 salvato.
# Batch 274 salvato.
# Batch 275 salvato.
# Batch 276 salvato.
# Batch 277 salvato.
# Batch 278 salvato.
# Batch 279 salvato.
# Batch 280 salvato.
# Batch 281 salvato.
# Batch 282 salvato.
# Batch 283 salvato.
# Batch 284 salvato.
# Batch 285 salvato.
# Batch 286 salvato.
# Batch 287 salvato.
# Batch 288 salvato.
# Batch 289 salvato.
# Batch 290 salvato.
# Batch 291 salvato.
# Batch 292 salvato.
# Batch 293 salvato.
# Batch 294 salvato.
# Batch 295 salvato.
# Batch 296 salvato.
# Batch 297 salvato.
# Batch 298 salvato.
# Batch 299 salvato.
# Batch 300 salvato.
# Batch 301 salvato.
# Batch 302 salvato.
# Batch 303 salvato.
# Batch 304 salvato.
# Batch 305 salvato.
# Batch 306 salvato.
# Batch 307 salvato.
# Batch 308 salvato.
# Batch 309 salvato.
# Batch 310 salvato.
# Batch 311 salvato.
# Batch 312 salvato.
# Batch 313 salvato.
# Batch 314 salvato.
# Batch 315 salvato.
# Batch 316 salvato.
# Batch 317 salvato.
# Batch 318 salvato.
# Batch 319 salvato.
# Batch 320 salvato.
# Batch 321 salvato.
# Batch 322 salvato.
# Batch 323 salvato.
# Batch 324 salvato.
# Batch 325 salvato.
# Batch 326 salvato.
# Batch 327 salvato.
# Batch 328 salvato.
# Batch 329 salvato.
# Batch 330 salvato.
# Batch 331 salvato.
# Batch 332 salvato.
# Batch 333 salvato.
# Batch 334 salvato.
# Batch 335 salvato.
# Batch 336 salvato.
# Batch 337 salvato.
# Batch 338 salvato.
# Batch 339 salvato.
# Batch 340 salvato.
# Batch 341 salvato.
# Batch 342 salvato.
# Batch 343 salvato.
# Batch 344 salvato.
# Batch 345 salvato.
# Batch 346 salvato.
# Batch 347 salvato.
# Batch 348 salvato.
# Batch 349 salvato.
# Batch 350 salvato.
# Batch 351 salvato.
# Batch 352 salvato.
# Batch 353 salvato.
# Batch 354 salvato.
# Batch 355 salvato.
# Batch 356 salvato.
# Batch 357 salvato.
# Batch 358 salvato.
# Batch 359 salvato.
# Batch 360 salvato.
# Batch 361 salvato.
# Batch 362 salvato.
# Batch 363 salvato.
# Batch 364 salvato.
# Batch 365 salvato.
# Batch 366 salvato.
# Batch 367 salvato.
# Batch 368 salvato.
# Batch 369 salvato.
# Batch 370 salvato.
# Batch 371 salvato.
# Batch 372 salvato.
# Batch 373 salvato.
# Batch 374 salvato.
# Batch 375 salvato.
# Batch 376 salvato.
# Batch 377 salvato.
# Batch 378 salvato.
# Batch 379 salvato.
# Batch 380 salvato.
# Batch 381 salvato.
# Batch 382 salvato.
# Batch 383 salvato.
# Batch 384 salvato.
# Batch 385 salvato.
# Batch 386 salvato.
# Batch 387 salvato.
# Batch 388 salvato.
# Batch 389 salvato.
# Batch 390 salvato.
# Batch 0 salvato.
# Batch 1 salvato.
# Batch 2 salvato.
# Batch 3 salvato.
# Batch 4 salvato.
# Batch 5 salvato.
# Batch 6 salvato.
# Batch 7 salvato.
# Batch 8 salvato.
# Batch 9 salvato.
# Batch 10 salvato.
# Batch 11 salvato.
# Batch 12 salvato.
# Batch 13 salvato.
# Batch 14 salvato.
# Batch 15 salvato.
# Batch 16 salvato.
# Batch 17 salvato.
# Batch 18 salvato.
# Batch 19 salvato.
# Batch 20 salvato.
# Batch 21 salvato.
# Batch 22 salvato.
# Batch 23 salvato.
# Batch 24 salvato.
# Batch 25 salvato.
# Batch 26 salvato.
# Batch 27 salvato.
# Batch 28 salvato.
# Batch 29 salvato.
# Batch 30 salvato.
# Batch 31 salvato.
# Batch 32 salvato.
# Batch 33 salvato.
# Batch 34 salvato.
# Batch 35 salvato.
# Batch 36 salvato.
# Batch 37 salvato.
# Batch 38 salvato.
# Batch 39 salvato.
# Batch 40 salvato.
# Batch 41 salvato.
# Batch 42 salvato.
# Batch 43 salvato.
# Batch 44 salvato.
# Batch 45 salvato.
# Batch 46 salvato.
# Batch 47 salvato.
# Batch 48 salvato.
# Batch 49 salvato.
# Batch 50 salvato.
# Batch 51 salvato.
# Batch 52 salvato.
# Batch 53 salvato.
# Batch 54 salvato.
# Batch 55 salvato.
# Batch 56 salvato.
# Batch 57 salvato.
# Batch 58 salvato.
# Batch 59 salvato.
# Batch 60 salvato.
# Batch 61 salvato.
# Batch 62 salvato.
# Batch 63 salvato.
# Batch 64 salvato.
# Batch 65 salvato.
# Batch 66 salvato.
# Batch 67 salvato.
# Batch 68 salvato.
# Batch 69 salvato.
# Batch 70 salvato.
# Batch 71 salvato.
# Batch 72 salvato.
# Batch 73 salvato.
# Batch 74 salvato.
# Batch 75 salvato.
# Batch 76 salvato.
# Batch 77 salvato.
# Batch 78 salvato.
# Batch 79 salvato.
# Batch 80 salvato.
# Batch 81 salvato.
# Batch 82 salvato.
# Batch 83 salvato.
# Batch 84 salvato.
# Batch 85 salvato.
# Batch 86 salvato.
# Batch 87 salvato.
# Batch 88 salvato.
# Batch 89 salvato.
# Batch 90 salvato.
# Batch 91 salvato.
# Batch 92 salvato.
# Batch 93 salvato.
# Batch 94 salvato.
# Batch 95 salvato.
# Batch 96 salvato.
# Batch 97 salvato.
# Batch 98 salvato.
# Batch 99 salvato.
# Batch 100 salvato.
# Batch 101 salvato.
# Batch 102 salvato.
# Batch 103 salvato.
# Batch 104 salvato.
# Batch 105 salvato.
# Batch 106 salvato.
# Batch 107 salvato.
# Batch 108 salvato.
# Batch 109 salvato.
# Batch 110 salvato.
# Batch 111 salvato.
# Batch 112 salvato.
# Batch 113 salvato.
# Batch 114 salvato.
# Batch 115 salvato.
# Batch 116 salvato.
# Batch 117 salvato.
# Batch 118 salvato.
# Batch 119 salvato.
# Batch 120 salvato.
# Batch 121 salvato.
# Batch 122 salvato.
# Batch 123 salvato.
# Batch 124 salvato.
# Batch 125 salvato.
# Batch 126 salvato.
# Batch 127 salvato.
# Batch 128 salvato.
# Batch 129 salvato.
# Batch 130 salvato.
# Batch 131 salvato.
# Batch 132 salvato.
# Batch 133 salvato.
# Batch 134 salvato.
# Batch 135 salvato.
# Batch 136 salvato.
# Batch 137 salvato.
# Batch 138 salvato.
# Batch 139 salvato.
# Batch 140 salvato.
# Batch 141 salvato.

# %%
merge_batches_to_npz('features/', prefix='train', out_path='train_features.npz')
merge_batches_to_npz('features/', prefix='val',   out_path='val_features.npz')
merge_batches_to_npz('features/', prefix='test',  out_path='test_features.npz')
# Out:
# Salvato train in train_features.npz
# Salvato val in val_features.npz
# Salvato test in test_features.npz

# %%
train = np.load('train_features.npz')
X_train, y_train = train['X'], train['y']

val = np.load('val_features.npz')
X_val, y_val = val['X'], val['y']

test = np.load('test_features.npz')
X_test, y_test = test['X'], test['y']

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import Ridge, Lasso, LinearRegression

class IdentityTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None): return self
    def transform(self, X): return X

# %%
scalers = {
    'none': IdentityTransformer(),
    'standard': StandardScaler(),
    'minmax': MinMaxScaler(),
}

reducers = {
    'none': IdentityTransformer(),
    'pca_10': PCA(n_components=10),
    'pca_20': PCA(n_components=20),
    'knn': SelectKBest(mutual_info_regression, k=16)
}

# %%
# SVR
svr = SVR(C=1,epsilon=0.5,kernel='poly',degree=5)

# XGBoost
xgboost = xgb.XGBRegressor(n_estimators=50, learning_rate=0.1, max_depth=1, verbosity=0, random_state=42)

# Ensemble tra LinearRegression e SVR
ensemble = VotingRegressor(estimators=[
    ('lr', LinearRegression()),
    ('svr', svr)
])

models = {
   'linear': LinearRegression(),
   'ridge': Ridge(),
   'svr': svr,
   'xgb': xgboost,
   'ensemble': ensemble,
}

# %%
import itertools
combinations = list(itertools.product(scalers.items(), reducers.items(), models.items()))

# %%
def evaluate_combinations(X_train, y_train, X_test, y_test, selected_combinations, scalers, reducers, models):

    results = []

    for (scaler_name, scaler_obj), (reducer_name, reducer_obj), (model_name, model_obj) in selected_combinations:
        print(f"Testing: scaler={scaler_name}, reducer={reducer_name}, model={model_name}")

        pipe = Pipeline([
            ('scaler', scaler_obj),
            ('reducer', reducer_obj),
            ('model', model_obj)
        ])

        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
        ccc_score=ccc(y_test, y_pred)

        results.append({
            'scaler': scaler_name,
            'reducer': reducer_name,
            'model': model_name,
            'ccc': ccc_score
        })

    return pd.DataFrame(results).sort_values(by='ccc')

# %%
df_results = evaluate_combinations(X_train, y_train, X_test, y_test, combinations, scalers, reducers, models)
pd.set_option('display.max_rows', None)
print(df_results)
# Out:
# Testing: scaler=none, reducer=none, model=linear
# Testing: scaler=none, reducer=none, model=ridge
# Testing: scaler=none, reducer=none, model=svr
# Testing: scaler=none, reducer=none, model=xgb
# Testing: scaler=none, reducer=none, model=ensemble
# Testing: scaler=none, reducer=pca_10, model=linear
# Testing: scaler=none, reducer=pca_10, model=ridge
# Testing: scaler=none, reducer=pca_10, model=svr
# Testing: scaler=none, reducer=pca_10, model=xgb
# Testing: scaler=none, reducer=pca_10, model=ensemble
# Testing: scaler=none, reducer=pca_20, model=linear
# Testing: scaler=none, reducer=pca_20, model=ridge
# Testing: scaler=none, reducer=pca_20, model=svr
# Testing: scaler=none, reducer=pca_20, model=xgb
# Testing: scaler=none, reducer=pca_20, model=ensemble
# Testing: scaler=none, reducer=knn, model=linear
# Testing: scaler=none, reducer=knn, model=ridge
# Testing: scaler=none, reducer=knn, model=svr
# Testing: scaler=none, reducer=knn, model=xgb
# Testing: scaler=none, reducer=knn, model=ensemble
# Testing: scaler=standard, reducer=none, model=linear
# Testing: scaler=standard, reducer=none, model=ridge
# Testing: scaler=standard, reducer=none, model=svr
# Testing: scaler=standard, reducer=none, model=xgb
# Testing: scaler=standard, reducer=none, model=ensemble
# Testing: scaler=standard, reducer=pca_10, model=linear
# Testing: scaler=standard, reducer=pca_10, model=ridge
# Testing: scaler=standard, reducer=pca_10, model=svr
# Testing: scaler=standard, reducer=pca_10, model=xgb
# Testing: scaler=standard, reducer=pca_10, model=ensemble
# Testing: scaler=standard, reducer=pca_20, model=linear
# Testing: scaler=standard, reducer=pca_20, model=ridge
# Testing: scaler=standard, reducer=pca_20, model=svr
# Testing: scaler=standard, reducer=pca_20, model=xgb
# Testing: scaler=standard, reducer=pca_20, model=ensemble
# Testing: scaler=standard, reducer=knn, model=linear
# Testing: scaler=standard, reducer=knn, model=ridge
# Testing: scaler=standard, reducer=knn, model=svr
# Testing: scaler=standard, reducer=knn, model=xgb
# Testing: scaler=standard, reducer=knn, model=ensemble
# Testing: scaler=minmax, reducer=none, model=linear
# Testing: scaler=minmax, reducer=none, model=ridge
# Testing: scaler=minmax, reducer=none, model=svr
# Testing: scaler=minmax, reducer=none, model=xgb
# Testing: scaler=minmax, reducer=none, model=ensemble
# Testing: scaler=minmax, reducer=pca_10, model=linear
# Testing: scaler=minmax, reducer=pca_10, model=ridge
# Testing: scaler=minmax, reducer=pca_10, model=svr
# Testing: scaler=minmax, reducer=pca_10, model=xgb
# Testing: scaler=minmax, reducer=pca_10, model=ensemble
# Testing: scaler=minmax, reducer=pca_20, model=linear
# Testing: scaler=minmax, reducer=pca_20, model=ridge
# Testing: scaler=minmax, reducer=pca_20, model=svr
# Testing: scaler=minmax, reducer=pca_20, model=xgb
# Testing: scaler=minmax, reducer=pca_20, model=ensemble
# Testing: scaler=minmax, reducer=knn, model=linear
# Testing: scaler=minmax, reducer=knn, model=ridge
# Testing: scaler=minmax, reducer=knn, model=svr
# Testing: scaler=minmax, reducer=knn, model=xgb
# Testing: scaler=minmax, reducer=knn, model=ensemble
#       scaler reducer     model       ccc
# 27  standard  pca_10       svr  0.107047
# 47    minmax  pca_10       svr  0.117372
# 32  standard  pca_20       svr  0.157229
# 52    minmax  pca_20       svr  0.162290
# 22  standard    none       svr  0.170629
# 29  standard  pca_10  ensemble  0.177736
# 49    minmax  pca_10  ensemble  0.183756
# 15      none     knn    linear  0.196682
# 55    minmax     knn    linear  0.196682
# 35  standard     knn    linear  0.196682
# 36  standard     knn     ridge  0.196882
# 34  standard  pca_20  ensemble  0.201983
# 56    minmax     knn     ridge  0.203321
# 54    minmax  pca_20  ensemble  0.203745
# 12      none  pca_20       svr  0.207501
# 23  standard    none       xgb  0.211773
# 3       none    none       xgb  0.211773
# 43    minmax    none       xgb  0.211773
# 5       none  pca_10    linear  0.218599
# 6       none  pca_10     ridge  0.219158
# 39  standard     knn  ensemble  0.224957
# 14      none  pca_20  ensemble  0.226763
# 16      none     knn     ridge  0.227081
# 58    minmax     knn       xgb  0.228345
# 38  standard     knn       xgb  0.228345
# 18      none     knn       xgb  0.228345
# 10      none  pca_20    linear  0.230610
# 11      none  pca_20     ridge  0.230855
# 50    minmax  pca_20    linear  0.233780
# 51    minmax  pca_20     ridge  0.233795
# 37  standard     knn       svr  0.235044
# 28  standard  pca_10       xgb  0.235255
# 33  standard  pca_20       xgb  0.235255
# 30  standard  pca_20    linear  0.237360
# 31  standard  pca_20     ridge  0.237360
# 53    minmax  pca_20       xgb  0.237502
# 48    minmax  pca_10       xgb  0.237502
# 13      none  pca_20       xgb  0.240624
# 8       none  pca_10       xgb  0.240624
# 25  standard  pca_10    linear  0.246507
# 26  standard  pca_10     ridge  0.246507
# 45    minmax  pca_10    linear  0.247168
# 46    minmax  pca_10     ridge  0.247172
# 24  standard    none  ensemble  0.248035
# 9       none  pca_10  ensemble  0.252253
# 59    minmax     knn  ensemble  0.257020
# 21  standard    none     ridge  0.269295
# 7       none  pca_10       svr  0.271154
# 1       none    none     ridge  0.278574
# 42    minmax    none       svr  0.284059
# 44    minmax    none  ensemble  0.300798
# 40    minmax    none    linear  0.301126
# 20  standard    none    linear  0.306810
# 57    minmax     knn       svr  0.306968
# 19      none     knn  ensemble  0.315040
# 41    minmax    none     ridge  0.315145
# 2       none    none       svr  0.324293
# 4       none    none  ensemble  0.362497
# 0       none    none    linear  0.380264
# 17      none     knn       svr  0.399917
